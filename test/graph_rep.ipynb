# %%
import json

# %%
with open('../ext/output/edges.json') as fr:
    data = [json.loads(line) for line in fr]

# %%
print(data[:10])
# Out:
# [{'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/dev/tty', 'type': 'action', 'value': 'Read_Write'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/etc/ld.so.cache', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/etc/localtime', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/lib/x86_64-linux-gnu/libc-2.28.so', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/lib/x86_64-linux-gnu/libc.so.6', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/lib/x86_64-linux-gnu/libcrypt-2.28.so', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/lib/x86_64-linux-gnu/libcrypt.so.1', 'type': 'action', 'value': 'Read'}, {'source': 'pulp_rpm_client_3.19.0.dev1666065560', 'target': '/lib/x86_64-linux-gnu/libdl-2.28.so', 'type': 
# ...

# %%
import pandas as pd

edges_df = pd.DataFrame(data)

# %%
edges_df.head()
# Out:
#                                  source                              target  \
# 0  pulp_rpm_client_3.19.0.dev1666065560                            /dev/tty
# 1  pulp_rpm_client_3.19.0.dev1666065560                    /etc/ld.so.cache
# 2  pulp_rpm_client_3.19.0.dev1666065560                      /etc/localtime
# 3  pulp_rpm_client_3.19.0.dev1666065560  /lib/x86_64-linux-gnu/libc-2.28.so
# 4  pulp_rpm_client_3.19.0.dev1666065560     /lib/x86_64-linux-gnu/libc.so.6
#
#      type       value
# 0  action  Read_Write
# 1  action        Read
# 2  action        Read
# 3  action        Read
# 4  action        Read

# %%
with open('../ext/output/nodes.json') as fr:
    nodes = [json.loads(line) for line in fr]

# %%
print(nodes[:10])

# %%
nodes_df = pd.DataFrame(nodes)

# %%
nodes_df.head()
