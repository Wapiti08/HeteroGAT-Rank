# %%
import matplotlib.pyplot as plt

# Epochs
epochs = list(range(1, 16))

# Loss values for each model
loss_diff = [1.3623, 1.3151, 1.2956, 1.2821, 1.2665, 1.2666, 1.2585, 1.2590, 1.2542, 1.2520, 1.2544, 1.2512, 1.2558, 1.2503, 1.2419]
loss_pn = [1.3529, 1.3149, 1.2878, 1.2648, 1.2717, 1.2617, 1.2556, 1.2605, 1.2488, 1.2570, 1.2500, 1.2532, 1.2543, 1.2452, 1.2549]
loss_hetero = [0.5036623609470733, 0.4249388638101978, 0.3895659425560339, 0.3515426846749989,
                0.33172787229220074, 0.3199173946071554, 0.29964209660703756, 0.2938819062654619,
                0.28399733969090896, 0.2831006203720599, 0.2757382284803891, 0.26428397855273,
                0.2668138820172092, 0.26225479172519695, 0.27054354718621865]

# Plot
plt.figure()
plt.plot(epochs, loss_diff, marker='o', label='DiffHeteroGAT')
plt.plot(epochs, loss_pn, marker='s', color='red', label='PNHeteroGAT')
plt.plot(epochs, loss_hetero, marker='^', label='HeteroGAT')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
plt.legend()
# plt.title('Training Loss Comparison Across Models')
plt.grid(True)
plt.show()
