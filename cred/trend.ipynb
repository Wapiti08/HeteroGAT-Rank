# %%
# !pip3 install matplotlib==3.10.3
# !pip3 install seaborn==0.13.2
# Out:
# Requirement already satisfied: matplotlib==3.10.3 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib==3.10.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.10.3) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Collecting seaborn==0.13.2
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from seaborn==0.13.2) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from seaborn==0.13.2) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/zhuoran/.pyenv/versions/3.10.14/envs/DDGRL/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
'''
 # @ Create Time: 2025-06-15 11:17:36
 # @ Modified time: 2025-06-15 11:17:58
 # @ Description: based on ioc_metrics.csv, visualize the trends of IoC behaviors, 
 used to analyze the relibility of top features from different methods
 ''' 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("ioc_metrics.csv")

fields = ['location', 'function', 'attack_type', 'trigger_mechanism', 'hide']
trend_counts = {field: df[field].value_counts() for field in fields}

# 可视化趋势
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
axes = axes.flatten()

for i, field in enumerate(fields):
    sns.barplot(x=trend_counts[field].values, y=trend_counts[field].index, ax=axes[i])
    axes[i].set_title(f"{field} Trend")
    axes[i].set_xlabel("Count")
    axes[i].set_ylabel("")

plt.tight_layout()
plt.suptitle("IoC Behavior Trends", fontsize=16, y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       8 import pandas as pd
#       9 import matplotlib.pyplot as plt
# ---> 10 import seaborn as sns
#      12 df = pd.read_csv("ioc_metrics.csv")
#      14 fields = ['location', 'function', 'attack_type', 'trigger_mechanism', 'hide']
#
# ModuleNotFoundError: No module named 'seaborn'
